# %%
import pandas as pd
import numpy as np
df = pd.DataFrame({'A':['Sai','Sai','Subu','Yuvi','Rithi','Subu'],
                   'B':['one','one','three','one','three','three'],
                   'C':np.random.randint(5,size=6),
                   'D':np.random.randint(5,size=6),
                   'E':np.random.randint(5,size=6)})
print("\nOriginal DataFrame\n",df)
# Out:
# Original DataFrame
#         A      B  C  D  E
# 0    Sai    one  2  4  1
# 1    Sai    one  2  3  3
# 2   Subu  three  4  1  0
# 3   Yuvi    one  1  2  1
# 4  Rithi  three  2  0  4
# 5   Subu  three  1  0  4

# %%
#Group by (multi column): with one column sum
df1=df.groupby(['A','B'],as_index=False)['C'].sum()
print("\nOriginal DataFrame\n",df)
print("\ngroup by (multi column):with one column sum\n",df1)
# Out:
# Original DataFrame
#         A      B  C  D  E
# 0    Sai    one  2  4  1
# 1    Sai    one  2  3  3
# 2   Subu  three  4  1  0
# 3   Yuvi    one  1  2  1
# 4  Rithi  three  2  0  4
# 5   Subu  three  1  0  4
#
# group by (multi column):with one column sum
#         A      B  C
# 0  Rithi  three  2
# 1    Sai    one  4
# 2   Subu  three  5
# 3   Yuvi    one  1

# %%
#Group by (multi-column): with multi column sum
df2 = df.groupby(['A','B'], as_index=False).sum()
print("\nOriginal DataFrame\n",df)
print("\nGroup by (multi-column): with multi columns sum\n",df2)
# Out:
# Original DataFrame
#         A      B  C  D  E
# 0    Sai    one  2  4  1
# 1    Sai    one  2  3  3
# 2   Subu  three  4  1  0
# 3   Yuvi    one  1  2  1
# 4  Rithi  three  2  0  4
# 5   Subu  three  1  0  4
#
# Group by (multi-column): with multi columns sum
#         A      B  C  D  E
# 0  Rithi  three  2  0  4
# 1    Sai    one  4  7  4
# 2   Subu  three  5  1  4
# 3   Yuvi    one  1  2  1

# %%
#combined groupby and aggregate function
df3 = df.groupby(['A','B'],as_index=False)['C'].agg('sum')
print("\nOriginal DataFrame\n",df)
print("\nCombined Groupby and Aggregate function\n",df3)
# Out:
# Original DataFrame
#         A      B  C  D  E
# 0    Sai    one  2  4  1
# 1    Sai    one  2  3  3
# 2   Subu  three  4  1  0
# 3   Yuvi    one  1  2  1
# 4  Rithi  three  2  0  4
# 5   Subu  three  1  0  4
#
# Combined Groupby and Aggregate function
#         A      B  C
# 0  Rithi  three  2
# 1    Sai    one  4
# 2   Subu  three  5
# 3   Yuvi    one  1

# %%
#combined groupby and aggregate function – separate column headings

df4 = (df.groupby(['A','B']).agg([('average','mean'),('total','sum')]))
print("\nOriginal DataFrame\n",df)
print("\nCombined Groupby and Aggregate function-separate column headings\n",df4)
# Out:
# Original DataFrame
#         A      B  C  D  E
# 0    Sai    one  2  4  1
# 1    Sai    one  2  3  3
# 2   Subu  three  4  1  0
# 3   Yuvi    one  1  2  1
# 4  Rithi  three  2  0  4
# 5   Subu  three  1  0  4
#
# Combined Groupby and Aggregate function-separate column headings
#                    C             D             E
#             average total average total average total
# A     B
# Rithi three     2.0     2     0.0     0     4.0     4
# Sai   one       2.0     4     3.5     7     2.0     4
# Subu  three     2.5     5     0.5     1     2.0     4
# Yuvi  one       1.0     1     2.0     2     1.0     1

# %%
df5 = df.groupby(['A','B'],as_index=False).sum()
df6 = (df.groupby(['A','B']).agg(['sum']))
print("\nOriginal DataFrame\n",df)
print("\nGroupby-sum function\n",df5)
print("\nGroupby and Aggregate - sum function\n",df6)
# Out:
# Original DataFrame
#         A      B  C  D  E
# 0    Sai    one  2  4  1
# 1    Sai    one  2  3  3
# 2   Subu  three  4  1  0
# 3   Yuvi    one  1  2  1
# 4  Rithi  three  2  0  4
# 5   Subu  three  1  0  4
#
# Groupby-sum function
#         A      B  C  D  E
# 0  Rithi  three  2  0  4
# 1    Sai    one  4  7  4
# 2   Subu  three  5  1  4
# 3   Yuvi    one  1  2  1
#
# Groupby and Aggregate - sum function
#                C   D   E
#             sum sum sum
# A     B
# Rithi three   2   0   4
# Sai   one     4   7   4
# Subu  three   5   1   4
# Yuvi  one     1   2   1
