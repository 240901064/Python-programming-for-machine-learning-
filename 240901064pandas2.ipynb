# %%
import pandas as pd
import numpy as np
#Dataframe.apply function
print("DataFrame.apply function:\n")
info=pd.DataFrame([[2,7]]*3,columns=['P','Q'])
print("\nOriginal  DataFrame:\n",info)
print("\nSquare root of DataFrame:\n",info.apply(np.sqrt))
print("\nSum of each column:\n",info.apply(np.sum,axis=0))
print("\nSum of each row:\n",info.apply(np.sum,axis=1))
# Out:
# DataFrame.apply function:
#
#
# Original  DataFrame:
#     P  Q
# 0  2  7
# 1  2  7
# 2  2  7
#
# Square root of DataFrame:
#            P         Q
# 0  1.414214  2.645751
# 1  1.414214  2.645751
# 2  1.414214  2.645751
#
# Sum of each column:
#  P     6
# Q    21
# dtype: int64
#
# Sum of each row:
#  0    9
# 1    9
# 2    9
# dtype: int64

# %%
info=pd.DataFrame([[1,5,7],[2,7,8],[3,6,9]],columns=['X','Y','Z'])
print("\nOriginal DataFrame:\n",info)
print("\nMinimum and Maximum of each column:\n")
print(info.agg(['min','max']))
# Out:
# Original DataFrame:
#     X  Y  Z
# 0  1  5  7
# 1  2  7  8
# 2  3  6  9
#
# Minimum and Maximum of each column:
#
#      X  Y  Z
# min  1  5  7
# max  3  7  9

# %%
#DataFrame.Assign function
print("\nDataFrame.Assign function:\n")
d2=pd.DataFrame([['Nans',125],['Sennila',257]],columns=['Emp','ID'])
print("\nOriginal DataFrame:\n",d2)
d2['Age']=[18,19]
print("\nAdding new column:\n",d2)
d=d2.assign(sex=['Female','Female'])
print("\nAdding new column:\n",d)
# Out:
# DataFrame.Assign function:
#
#
# Original DataFrame:
#         Emp   ID
# 0     Nans  125
# 1  Sennila  257
#
# Adding new column:
#         Emp   ID  Age
# 0     Nans  125   18
# 1  Sennila  257   19
#
# Adding new column:
#         Emp   ID  Age     sex
# 0     Nans  125   18  Female
# 1  Sennila  257   19  Female

# %%
#DataFrame.Sort function
print("DataFrame.Sort function:\n")
info=pd.DataFrame(np.random.randn(5,2),index=[3,2,0,4,1],columns=['col3','col4'])
print(info)
info2=info.sort_index()
print("\nsort index:\n",info2)
#info=pd.DataFrame({'col1:[7,1,8,3],'col2':[8,12,4,9]})
info3=info.sort_values(by='col3')
print("\nSort Values:\n",info3)
# Out:
# DataFrame.Sort function:
#
#        col3      col4
# 3 -1.212993 -0.196008
# 2 -2.183595 -1.414188
# 0 -1.863570 -0.216718
# 4 -0.218742  2.696445
# 1 -0.510267  1.226565
#
# sort index:
#         col3      col4
# 0 -1.863570 -0.216718
# 1 -0.510267  1.226565
# 2 -2.183595 -1.414188
# 3 -1.212993 -0.196008
# 4 -0.218742  2.696445
#
# Sort Values:
#         col3      col4
# 2 -2.183595 -1.414188
# 0 -1.863570 -0.216718
# 3 -1.212993 -0.196008
# 1 -0.510267  1.226565
# 4 -0.218742  2.696445

# %%
#DataFrame.Merge function
print("\nDataFrame.Merge function:\n")
left=pd.DataFrame({'id':[1,2,3,4,5],'Name':['Nans','Revathi','sennila','Dhiya','Marans'],
'sub':['sub1','sub2','sub4','sub6','sub5']})
right=pd.DataFrame({'id':[1,2,3,4,5],'Name':['Bily','brian','sans','bento','nithya'],
'sub':['sub2','sub4','sub3','sub6','sub5']})
print(left)
print(right)
print(pd.merge(left,right,on='id'))
# Out:
# DataFrame.Merge function:
#
#    id     Name   sub
# 0   1     Nans  sub1
# 1   2  Revathi  sub2
# 2   3  sennila  sub4
# 3   4    Dhiya  sub6
# 4   5   Marans  sub5
#    id    Name   sub
# 0   1    Bily  sub2
# 1   2   brian  sub4
# 2   3    sans  sub3
# 3   4   bento  sub6
# 4   5  nithya  sub5
#    id   Name_x sub_x  Name_y sub_y
# 0   1     Nans  sub1    Bily  sub2
# 1   2  Revathi  sub2   brian  sub4
# 2   3  sennila  sub4    sans  sub3
# 3   4    Dhiya  sub6   bento  sub6
# 4   5   Marans  sub5  nithya  sub5
